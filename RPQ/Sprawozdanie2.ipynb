# %%
import random
from Carlier import Carlier
from Task import Task
import matplotlib.pyplot as plt
from time import perf_counter
import Load

# %%
tasks = Load.readData("Data/in50.txt")
cr_ = Carlier(100000)
print(f"Carlier  :{cr_.carlier(tasks)[0]}")
cr_ = Carlier(100000)
print(f"Carlier z heapq :{cr_.carlier_heapq(tasks)[0]}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-8d6a6ae42aa4> in <module>
#       1 tasks = Load.readData("Data/in50.txt")
#       2 cr_ = Carlier(100000)
# ----> 3 print(f"Carlier  :{cr_.carlier(tasks)[0]}")
#       4 cr_ = Carlier(100000)
#       5 print(f"Carlier z heapq :{cr_.carlier_heapq(tasks)[0]}")
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      67
#      68         LB = schrage.schrage_pmtn(tasks)
# ---> 69         if LB < self.UB:
#      70             self.carlier(tasks)
#      71
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      75
#      76         LB = schrage.schrage_pmtn(tasks)
# ---> 77         if LB < self.UB:
#      78             self.carlier(tasks)
#      79
#
# ~/Programming/SPDlab/RPQ/Carlier.py in carlier(self, tasks)
#      49
#      50     def carlier(self,tasks):
# ---> 51         order, U, C = schrage.schrage(tasks)
#      52         i = 0
#      53
#
# ~/Programming/SPDlab/RPQ/schrage.py in schrage(tasks)
#      13     while ready or not_ready:
#      14         while not_ready and min(task.get_r() for task in not_ready) <= t:
# ---> 15             e = min(not_ready, key=Task.get_r)
#      16             ready.add(e)
#      17             not_ready.remove(e)
#
# ~/Programming/SPDlab/RPQ/Task.py in get_r(self)
#      10         return f"Task {self.id}:   r={self.r}, p={self.p}, q={self.q}"
#      11
# ---> 12     def get_r(self):
#      13         return self.r
#      14
#
# KeyboardInterrupt:

# %%
dataset = []
length = [50, 100, 200, 300, 500, 800, 1000, 1400, 1800, 2500, 3000, 3500, 4000, 5000]
for i in length:
    tmp = []
    for n in range(1,i+1):
        tmp.append(Task(id=n, r=random.randint(0, 1000), p=random.randint(0, 1000), q=random.randint(0, 1000)))
    dataset.append(tmp)

times1 = []
times2 = []
leng = [len(x) for x in dataset]

for data in dataset:
    start = perf_counter()
    cr = Carlier(100000)
    cr.carlier(data)
    times1.append(perf_counter()-start)

    start = perf_counter()
    cr = Carlier(100000)
    cr.carlier_heapq(data)
    times2.append(perf_counter()-start)

plt.plot(leng, times1, label="Bez kolejki")
plt.plot(leng, times2, label="Z kolejką")
plt.legend()
plt.grid()
plt.title("Czas wykonania")
plt.xlabel("Liczba zadań")
plt.ylabel("Czas")
plt.show()
